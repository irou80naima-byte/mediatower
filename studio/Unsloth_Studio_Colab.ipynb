# %% [markdown]
# <a href="https://colab.research.google.com/github/irou80naima-byte/mediatower/blob/main/studio/Unsloth_Studio_Colab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# To run this, press "*Runtime*" and press "*Run all*" on a **free** Tesla T4 Google Colab instance!
# <div class="align-center">
# <a href="https://unsloth.ai/"><img src="https://github.com/unslothai/unsloth/raw/main/images/unsloth%20new%20logo.png" width="115"></a>
# <a href="https://discord.gg/unsloth"><img src="https://github.com/unslothai/unsloth/raw/main/images/Discord button.png" width="145"></a>
# <a href="https://unsloth.ai/docs/"><img src="https://github.com/unslothai/unsloth/blob/main/images/documentation%20green%20button.png?raw=true" width="125"></a> Join Discord if you need help + ⭐ <i>Star us on <a href="https://github.com/unslothai/unsloth">Github</a> </i> ⭐
# </div>
#
# To install Unsloth Studio on your local device, follow [our guide](https://unsloth.ai/docs/new/unsloth-studio/install). Unsloth Studio is licensed [AGPL-3.0](https://github.com/unslothai/unsloth/blob/main/studio/LICENSE.AGPL-3.0).
#
# ### Unsloth Studio
#
# Train and run open models with [**Unsloth Studio**](https://unsloth.ai/docs/new/unsloth-studio/start). NEW! Installation should now only take 2 mins!
#
#
# We are actively working on making Unsloth Studio install on Colab T4 GPUs faster.
#
# [Features](https://unsloth.ai/docs/new/unsloth-studio#features) • [Quickstart](https://unsloth.ai/docs/new/unsloth-studio/start) • [Data Recipes](https://unsloth.ai/docs/new/unsloth-studio/data-recipe) • [Unsloth Chat](https://unsloth.ai/docs/new/unsloth-studio/chat) • [Export](https://unsloth.ai/docs/new/unsloth-studio/export)

# %% [markdown]
# <p align="left"><img src="https://github.com/unslothai/unsloth/raw/main/studio/frontend/public/studio%20github%20landscape%20colab%20display.png" width="600"></p>

# %% [markdown]
# ### Setup: Clone repo and run setup

# %%
# !git clone --depth 1 --branch main https://github.com/unslothai/unsloth.git
# %cd /content/unsloth
# !chmod +x studio/setup.sh && ./studio/setup.sh --local
# Out:
# Cloning into 'unsloth'...
# remote: Enumerating objects: 6133, done.
# remote: Counting objects: 100% (6133/6133), done.
# remote: Compressing objects: 100% (5900/5900), done.
# remote: Total 6133 (delta 253), reused 3022 (delta 183), pack-reused 0 (from 0)
# Receiving objects: 100% (6133/6133), 40.56 MiB | 17.38 MiB/s, done.
# Resolving deltas: 100% (253/253), done.
# Updating files: 100% (5775/5775), done.
# /content/unsloth
#
#   🦥 Unsloth Studio Setup
#   ────────────────────────────────────────────────────
#                  local mode: overlaying /content/unsloth (editable) + unsloth-zoo from git main
#                  installing isolated Node (system Node/npm left untouched)...
#   node           v24.18.0 | npm 11.16.0 (isolated)
#                  installing bun...
#                  bun installed (1.4.2)
#                  building frontend...
#                  using bun for package install (faster)
#   frontend       built
#                  Colab detected, installing Unsloth backend dependencies...
#   python         backend deps installed into system Python
#                  continuing to llama.cpp install for GGUF inference support
#   deps           [==------------------]  2/17  base packages
#   deps           overlaying local repo (editable): /content/unsloth
#   deps           overlaying unsloth-zoo from git main
#   deps           [=======-------------]  6/17  dependency overrides
#                  torch 2.11.0+cu128 detected -- installing torchao==0.17.0 from
#                  https://download.pytorch.org/whl/cu128
#   deps           [====================] 17/17  torchcodec
#    torch 2.11.0+cu128 detected -- installing torchcodec>=0.11.0,<0.12.0 from https://download.pytorch.org/whl/cu128
#   deps           installed
#   transformers   5.3.0 pre-installed
#   transformers   5.5.0 pre-installed
#   transformers   5.10.2 pre-installed
#   gpu            Tesla T4 (sm_75)
#                  Driver: 580.82.07
#                  installing prebuilt llama.cpp...
#   llama.cpp      prebuilt installed and validated
#                  installed release: unslothai/llama.cpp@b11030-mix-5ff778e (tag b11030) -- cuda backend
#   whisper.cpp    prebuilt installed
#
#   ────────────────────────────────────────────────────
#   Unsloth Studio Setup Complete
#   ────────────────────────────────────────────────────
#                  from colab import start
#                  start()

# %% [markdown]
# ### Start Unsloth Studio

# %%
import sys
sys.path.insert(0, "/content/unsloth/studio/backend")
from colab import start

# On Colab, start() auto-opens a Cloudflare link and prints admin login credentials.
# Use the Cloudflare link above the ready card to open Unsloth (in-cell iframes often stay blank).
start()

# To skip the Cloudflare tunnel and try the in-notebook proxy iframe only:
# start(cloudflare=False)
# Out:
# 2026-09-21 07:10:27 [info     ] 🦥 Starting Unsloth Studio...
# {"timestamp": "2026-09-21T07:10:34.615276Z", "level": "info", "event": "   Loading backend..."}
# {"timestamp": "2026-09-21T07:10:34.641008Z", "level": "info", "event": "   Starting server..."}
# {"timestamp": "2026-09-21T07:10:34.643099Z", "level": "info", "event": "run_server startup begin api_only=False host=0.0.0.0 port=8888"}
# {"timestamp": "2026-09-21T07:10:34.793536Z", "level": "info", "event": "Imported FastAPI app in 112.3ms"}
# {"timestamp": "2026-09-21T07:10:34.802699Z", "level": "info", "event": "Ensured Unsloth directories in 161.1ms"}
# {"timestamp": "2026-09-21T07:10:34.867132Z", "level": "info", "event": "run_server pre-uvicorn setup completed in 225.5ms"}
# INFO:     Started server process [1045]
# INFO:     Waiting for application startup.
# {"timestamp": "2026-09-21T07:10:35.006099Z", "level": "info", "event": "Removing unsloth compiled cache: /root/.unsloth/studio/compiled_cache"}
# {"timestamp": "2026-09-21T07:10:35.505344Z", "level": "info", "event": "lifespan pre-auth setup completed in 501.7ms"}
#
# ============================================================
# DEFAULT ADMIN ACCOUNT CREATED
#     username: unsloth
#     password saved to: /root/.unsloth/studio/auth/.bootstrap_password
#     Open the Unsloth UI to sign in and change it.
# ============================================================
#
# {"timestamp": "2026-09-21T07:10:35.706961Z", "level": "info", "event": "lifespan startup completed in 703.3ms"}
# INFO:     Application startup complete.
# INFO:     Unsloth Studio running on http://172.28.0.12:8888 (To stop: press Ctrl+C -- on macOS, Control+C not Command+C)
# {"timestamp": "2026-09-21T07:10:35.722119Z", "level": "info", "event": "Uvicorn startup hook completed in 1080.5ms"}
# {"timestamp": "2026-09-21T07:10:35.722702Z", "level": "info", "event": "run_server uvicorn ready after 1081.1ms"}
# {"timestamp": "2026-09-21T07:10:35.858364Z", "level": "info", "event": "   Server started on port 8888!"}
# {"timestamp": "2026-09-21T07:10:38.792560Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/health", "status_code": 200, "process_time_ms": 1007.86}
# Hardware detected: CUDA -- Tesla T4
# {"timestamp": "2026-09-21T07:10:38.963748Z", "level": "info", "event": "InferenceOrchestrator initialized (subprocess mode)"}
# {"timestamp": "2026-09-21T07:10:54.015038Z", "level": "info", "event": "torch warm finished in 18308.3ms"}
# {"timestamp": "2026-09-21T07:10:58.926695Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/health", "status_code": 200, "process_time_ms": 3.11}
# {"timestamp": "2026-09-21T07:11:00.882730Z", "level": "info", "event": "\ud83c\udf10 Unsloth Studio URL: https://8888-gpu-t4-s-kkb-usw1b1-22fzonur16g7w-b.us-west1-1.prod.colab.dev"}
# {"timestamp": "2026-09-21T07:11:00.883680Z", "level": "info", "event": "\ud83d\udd17 Shareable Cloudflare link: https://family-makers-ware-span.trycloudflare.com"}
#     <div style="display: inline-block; padding: 20px; background: #ffffff; border: 2px solid #000000;
#                 border-radius: 12px; margin: 10px 0; font-family: system-ui, -apple-system, sans-serif;">
#         <h2 style="color: #000000; margin: 0 0 12px 0; font-size: 26px; font-weight: 800;
#                    display: flex; align-items: center; gap: 12px;">
#             <img src="https://github.com/unslothai/unsloth/raw/main/studio/frontend/public/unsloth-gem.png"
#                  height="48" style="display:block;">
#             Shareable Unsloth Link is Ready!
#         </h2>
#         <a href="https://family-makers-ware-span.trycloudflare.com" onclick="var w=window.open(this.href,'_blank');if(!w){return true;}return false;"
#            style="display: inline-flex; align-items: center; gap: 10px; padding: 14px 28px;
#                   background: #000000; color: white; text-decoration: none; border-radius: 8px;
#                   font-weight: 800; font-size: 16px; cursor: pointer;">
#             <svg xmlns="http://www.w3.org/2000/svg" width="18" height="18" viewBox="0 0 24 24" fill="white"><polygon points="5,3 19,12 5,21"/></svg>
#             Open Unsloth Studio
#         </a>
#         <p style="color: #333333; margin: 12px 0 0 0; font-size: 14px; font-weight: bold;">
#             This Cloudflare HTTPS link works from any device, so you can share it with anyone.
#         </p>
#         <p style="color: #333333; margin: 16px 0 0 0; font-size: 13px; font-family: monospace; font-weight: bold;">
#             🔗 <a href="https://family-makers-ware-span.trycloudflare.com" onclick="var w=window.open(this.href,'_blank');if(!w){return true;}return false;"
#                   style="color: #000000; text-decoration: underline; cursor: pointer;">https://family-makers-ware-span.trycloudflare.com</a>
#         </p>
#         <p style="color: #000000; margin: 16px 0 0 0; font-size: 20px; font-weight: 800;">
#             Password
#         </p>
#         <p style="margin: 6px 0 0 0;"><code style="display: inline-block; font-size: 24px;
#             font-weight: 800; text-decoration: underline; background: #f3f3f3;
#             padding: 4px 10px; border-radius: 6px;">DefuseOverpriceRebateUnpack</code></p>
#         <p style="color: #666666; margin: 6px 0 0 0; font-size: 12px;">
#             Log in as <code>unsloth</code> with this password. Shown only in your
#             notebook session, and never included in the shared link.
#         </p>
#     </div>
# {"timestamp": "2026-09-21T07:12:03.698044Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/", "status_code": 200, "process_time_ms": 8.2}
# {"timestamp": "2026-09-21T07:12:04.153403Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/crypto-boot.js", "status_code": 200, "process_time_ms": 7.94}
# {"timestamp": "2026-09-21T07:12:04.164103Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/theme-boot.js", "status_code": 200, "process_time_ms": 5.92}
# {"timestamp": "2026-09-21T07:12:04.186443Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/reload-snapshot.js", "status_code": 200, "process_time_ms": 21.6}
# {"timestamp": "2026-09-21T07:12:20.966466Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/health", "status_code": 200, "process_time_ms": 3.11}
# {"timestamp": "2026-09-21T07:12:21.770169Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/auth/status", "status_code": 200, "process_time_ms": 5.02}
# {"timestamp": "2026-09-21T07:12:32.898687Z", "level": "info", "event": "request_completed", "method": "POST", "path": "/api/auth/login", "status_code": 200, "process_time_ms": 89.07}
# {"timestamp": "2026-09-21T07:12:33.178140Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/health", "status_code": 200, "process_time_ms": 4.28}
# {"timestamp": "2026-09-21T07:12:33.524454Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/skills", "status_code": 200, "process_time_ms": 18.74}
# {"timestamp": "2026-09-21T07:12:33.537768Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/chat/settings", "status_code": 200, "process_time_ms": 17.9}
# {"timestamp": "2026-09-21T07:12:33.541325Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/rag/knowledge-bases", "status_code": 200, "process_time_ms": 25.85}
# {"timestamp": "2026-09-21T07:12:33.563621Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/models/list", "status_code": 200, "process_time_ms": 14.77}
# {"timestamp": "2026-09-21T07:12:33.567410Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/hub/hidden-models", "status_code": 200, "process_time_ms": 24.59}
# {"timestamp": "2026-09-21T07:12:33.713340Z", "level": "info", "event": "Fetched 40 top GGUF models"}
# {"timestamp": "2026-09-21T07:12:33.715041Z", "level": "info", "event": "Fetched 23 top hub models"}
# {"timestamp": "2026-09-21T07:12:34.002439Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/chat/threads/__LOCALID_gooUNIt", "status_code": 404, "process_time_ms": 12.32}
# {"timestamp": "2026-09-21T07:12:34.007502Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/hub/local", "status_code": 200, "process_time_ms": 16.67}
# {"timestamp": "2026-09-21T07:12:35.105724Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/settings/hugging-face-token", "status_code": 200, "process_time_ms": 10.91}
# {"timestamp": "2026-09-21T07:12:35.384793Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/chat/threads/__LOCALID_gooUNIt", "status_code": 404, "process_time_ms": 5.02}
# {"timestamp": "2026-09-21T07:12:36.703529Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/inference/monitor", "status_code": 200, "process_time_ms": 47.81}
# {"timestamp": "2026-09-21T07:12:36.766630Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/models/list", "status_code": 200, "process_time_ms": 32.77}
# {"timestamp": "2026-09-21T07:12:37.924566Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/inference/status", "status_code": 200, "process_time_ms": 1202.19}
# {"timestamp": "2026-09-21T07:12:37.946876Z", "level": "info", "event": "request_completed", "method": "POST", "path": "/api/settings/chat-preferences/migrate", "status_code": 200, "process_time_ms": 1203.19}
# {"timestamp": "2026-09-21T07:12:37.976404Z", "level": "info", "event": "ExportOrchestrator initialized (subprocess mode)"}
# {"timestamp": "2026-09-21T07:12:37.986713Z", "level": "info", "event": "Found 0 trained models in /root/.unsloth/studio/outputs"}
# {"timestamp": "2026-09-21T07:12:37.992344Z", "level": "info", "event": "Found 0 exported models in /root/.unsloth/studio/exports"}
# {"timestamp": "2026-09-21T07:12:37.991142Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/chat/threads/__LOCALID_gooUNIt", "status_code": 404, "process_time_ms": 32.59}
# {"timestamp": "2026-09-21T07:12:37.995341Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/chat/threads/__LOCALID_4VPHmlR", "status_code": 404, "process_time_ms": 35.91}
# {"timestamp": "2026-09-21T07:12:41.595739Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/openapi.json", "status_code": 200, "process_time_ms": 3460.0}
# {"timestamp": "2026-09-21T07:12:41.651536Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/models/list", "status_code": 200, "process_time_ms": 37.86}
# {"timestamp": "2026-09-21T07:12:41.677924Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/chat/threads/__LOCALID_4VPHmlR", "status_code": 404, "process_time_ms": 63.31}
# {"timestamp": "2026-09-21T07:12:41.771817Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/studio/update-status", "status_code": 200, "process_time_ms": 160.19}
# {"timestamp": "2026-09-21T07:12:42.599360Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/studio/update-status", "status_code": 200, "process_time_ms": 117.69}
# {"timestamp": "2026-09-21T07:12:48.662418Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/settings/embedding-model", "status_code": 200, "process_time_ms": 11.29}
# 🦥 Unsloth: Will patch your computer to enable 2x faster free finetuning.
# {"timestamp": "2026-09-21T07:12:48.795828Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/inference/status", "status_code": 200, "process_time_ms": 148.62}
# {"timestamp": "2026-09-21T07:12:48.806594Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/studio/download-transport-capabilities", "status_code": 200, "process_time_ms": 161.78}
# {"timestamp": "2026-09-21T07:12:48.835145Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/settings/openai-auto-switch", "status_code": 200, "process_time_ms": 185.71}
# {"timestamp": "2026-09-21T07:12:48.883964Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/settings/vram-budget", "status_code": 200, "process_time_ms": 40.56}
# {"timestamp": "2026-09-21T07:12:48.907421Z", "level": "info", "event": "Cached model scan: inspected=0 skipped_gguf=0 skipped_no_weights=0 returned=0"}
# {"timestamp": "2026-09-21T07:12:48.909736Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/hub/cached-gguf", "status_code": 200, "process_time_ms": 64.22}
# {"timestamp": "2026-09-21T07:12:48.919796Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/hub/cached-models", "status_code": 200, "process_time_ms": 71.53}
# {"timestamp": "2026-09-21T07:12:49.721143Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/inference/monitor", "status_code": 200, "process_time_ms": 9.85}
# {"timestamp": "2026-09-21T07:12:51.224481Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/hub/gguf-variants", "status_code": 200, "process_time_ms": 627.69}
# {"timestamp": "2026-09-21T07:12:51.247643Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/hub/cached-gguf", "status_code": 200, "process_time_ms": 117.37}
# {"timestamp": "2026-09-21T07:12:51.248364Z", "level": "info", "event": "Cached model scan: inspected=0 skipped_gguf=0 skipped_no_weights=0 returned=0"}
# {"timestamp": "2026-09-21T07:12:51.265177Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/hub/cached-models", "status_code": 200, "process_time_ms": 125.98}
# {"timestamp": "2026-09-21T07:12:51.272203Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/hub/local", "status_code": 200, "process_time_ms": 130.09}
# {"timestamp": "2026-09-21T07:12:51.533562Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/hub/gguf-variants", "status_code": 200, "process_time_ms": 1020.27}
# {"timestamp": "2026-09-21T07:12:57.392274Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/settings/download-transport", "status_code": 200, "process_time_ms": 8744.42}
# {"timestamp": "2026-09-21T07:12:59.437179Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/inference/status", "status_code": 200, "process_time_ms": 93.59}
# {"timestamp": "2026-09-21T07:13:01.033242Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/inference/monitor", "status_code": 200, "process_time_ms": 3.15}
# {"timestamp": "2026-09-21T07:13:10.201771Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/inference/status", "status_code": 200, "process_time_ms": 91.7}
# {"timestamp": "2026-09-21T07:13:11.582065Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/inference/monitor", "status_code": 200, "process_time_ms": 3.18}
# {"timestamp": "2026-09-21T07:13:20.830936Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/inference/status", "status_code": 200, "process_time_ms": 93.96}
# {"timestamp": "2026-09-21T07:13:22.134849Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/inference/monitor", "status_code": 200, "process_time_ms": 2.9}
# {"timestamp": "2026-09-21T07:13:26.898869Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/hub/gguf-variants", "status_code": 200, "process_time_ms": 196.65}
# {"timestamp": "2026-09-21T07:13:27.242320Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/hub/cached-gguf", "status_code": 200, "process_time_ms": 33.32}
# {"timestamp": "2026-09-21T07:13:27.244966Z", "level": "info", "event": "Cached model scan: inspected=0 skipped_gguf=0 skipped_no_weights=0 returned=0"}
# {"timestamp": "2026-09-21T07:13:27.248260Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/hub/local", "status_code": 200, "process_time_ms": 33.21}
# {"timestamp": "2026-09-21T07:13:27.250534Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/hub/cached-models", "status_code": 200, "process_time_ms": 38.25}
# {"timestamp": "2026-09-21T07:13:28.640098Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/hub/gguf-variants", "status_code": 200, "process_time_ms": 141.31}
# {"timestamp": "2026-09-21T07:13:30.874991Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/inference/status", "status_code": 200, "process_time_ms": 92.2}
# {"timestamp": "2026-09-21T07:13:32.735596Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/inference/monitor", "status_code": 200, "process_time_ms": 2.53}
# {"timestamp": "2026-09-21T07:13:38.007477Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/hub/gguf-variants", "status_code": 200, "process_time_ms": 171.86}
# {"timestamp": "2026-09-21T07:13:43.347467Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/inference/monitor", "status_code": 200, "process_time_ms": 3.09}
# {"timestamp": "2026-09-21T07:13:53.904410Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/inference/monitor", "status_code": 200, "process_time_ms": 3.03}
# {"timestamp": "2026-09-21T07:14:04.474136Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/inference/monitor", "status_code": 200, "process_time_ms": 3.79}
# {"timestamp": "2026-09-21T07:14:15.037082Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/inference/monitor", "status_code": 200, "process_time_ms": 3.65}
# {"timestamp": "2026-09-21T07:14:16.599645Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/hub/gguf-variants", "status_code": 200, "process_time_ms": 264.55}
# {"timestamp": "2026-09-21T07:14:16.933866Z", "level": "info", "event": "Cached model scan: inspected=0 skipped_gguf=0 skipped_no_weights=0 returned=0"}
# {"timestamp": "2026-09-21T07:14:16.936876Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/hub/cached-models", "status_code": 200, "process_time_ms": 21.79}
# {"timestamp": "2026-09-21T07:14:16.954157Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/hub/cached-gguf", "status_code": 200, "process_time_ms": 35.45}
# {"timestamp": "2026-09-21T07:14:16.959156Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/hub/local", "status_code": 200, "process_time_ms": 28.52}
# {"timestamp": "2026-09-21T07:14:24.866266Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/hub/gguf-variants", "status_code": 200, "process_time_ms": 226.02}
# {"timestamp": "2026-09-21T07:14:25.694911Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/inference/monitor", "status_code": 200, "process_time_ms": 3.16}
# {"timestamp": "2026-09-21T07:14:36.306396Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/inference/monitor", "status_code": 200, "process_time_ms": 2.94}
# {"timestamp": "2026-09-21T07:14:38.840409Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/hub/gguf-variants", "status_code": 200, "process_time_ms": 217.31}
# {"timestamp": "2026-09-21T07:14:46.847010Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/inference/monitor", "status_code": 200, "process_time_ms": 2.92}
# {"timestamp": "2026-09-21T07:14:51.516877Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/hub/gguf-variants", "status_code": 200, "process_time_ms": 264.29}
# {"timestamp": "2026-09-21T07:14:51.706568Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/hub/cached-gguf", "status_code": 200, "process_time_ms": 15.06}
# {"timestamp": "2026-09-21T07:14:51.720267Z", "level": "info", "event": "Cached model scan: inspected=0 skipped_gguf=0 skipped_no_weights=0 returned=0"}
# {"timestamp": "2026-09-21T07:14:51.733168Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/hub/cached-models", "status_code": 200, "process_time_ms": 30.83}
# {"timestamp": "2026-09-21T07:14:51.737755Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/hub/local", "status_code": 200, "process_time_ms": 28.27}
# {"timestamp": "2026-09-21T07:14:57.454436Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/inference/monitor", "status_code": 200, "process_time_ms": 2.92}
# {"timestamp": "2026-09-21T07:15:01.075145Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/settings/download-transport", "status_code": 200, "process_time_ms": 9.57}
# {"timestamp": "2026-09-21T07:15:01.739850Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/studio/download-transport-capabilities", "status_code": 200, "process_time_ms": 336.77}
# {"timestamp": "2026-09-21T07:15:02.966387Z", "level": "info", "event": "Download transport for unsloth/MiniMax-H3-GGUF: xet (Xet (requested))"}
# {"timestamp": "2026-09-21T07:15:03.025422Z", "level": "info", "event": "request_completed", "method": "POST", "path": "/api/hub/download", "status_code": 202, "process_time_ms": 388.24}
# {"timestamp": "2026-09-21T07:15:03.334553Z", "level": "info", "event": "request_completed", "method": "POST", "path": "/api/settings/xet-notice/reserve", "status_code": 200, "process_time_ms": 14.21}
# {"timestamp": "2026-09-21T07:15:05.826925Z", "level": "info", "event": "hub_download_progress", "repo_id": "unsloth/MiniMax-H3-GGUF", "variant": "minimax_h3_fl2va_pruned-Q4_K", "percent": 0}
# {"timestamp": "2026-09-21T07:15:08.126916Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/inference/monitor", "status_code": 200, "process_time_ms": 2.99}
# {"timestamp": "2026-09-21T07:15:18.698104Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/inference/monitor", "status_code": 200, "process_time_ms": 2.86}
# {"timestamp": "2026-09-21T07:15:26.081941Z", "level": "info", "event": "hub_download_progress", "repo_id": "unsloth/MiniMax-H3-GGUF", "variant": "minimax_h3_fl2va_pruned-Q4_K", "percent": 10}
# {"timestamp": "2026-09-21T07:15:29.281599Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/inference/monitor", "status_code": 200, "process_time_ms": 15.54}
# {"timestamp": "2026-09-21T07:15:30.796346Z", "level": "info", "event": "hub_download_progress", "repo_id": "unsloth/MiniMax-H3-GGUF", "variant": "minimax_h3_fl2va_pruned-Q4_K", "percent": 20}
# {"timestamp": "2026-09-21T07:15:39.830414Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/inference/monitor", "status_code": 200, "process_time_ms": 2.9}
# {"timestamp": "2026-09-21T07:15:46.160843Z", "level": "info", "event": "hub_download_progress", "repo_id": "unsloth/MiniMax-H3-GGUF", "variant": "minimax_h3_fl2va_pruned-Q4_K", "percent": 30}
# {"timestamp": "2026-09-21T07:15:50.211817Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/hub/gguf-variants", "status_code": 200, "process_time_ms": 214.29}
# {"timestamp": "2026-09-21T07:15:50.474921Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/inference/monitor", "status_code": 200, "process_time_ms": 2.93}
# {"timestamp": "2026-09-21T07:15:55.496251Z", "level": "info", "event": "hub_download_progress", "repo_id": "unsloth/MiniMax-H3-GGUF", "variant": "minimax_h3_fl2va_pruned-Q4_K", "percent": 40}
# ={"timestamp": "2026-09-21T07:16:01.050779Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/inference/monitor", "status_code": 200, "process_time_ms": 3.09}
# {"timestamp": "2026-09-21T07:16:04.029408Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/hub/gguf-variants", "status_code": 200, "process_time_ms": 336.05}
# {"timestamp": "2026-09-21T07:16:09.514719Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/hub/gguf-variants", "status_code": 200, "process_time_ms": 362.22}
# {"timestamp": "2026-09-21T07:16:11.389423Z", "level": "info", "event": "hub_download_progress", "repo_id": "unsloth/MiniMax-H3-GGUF", "variant": "minimax_h3_fl2va_pruned-Q4_K", "percent": 50}
# {"timestamp": "2026-09-21T07:16:11.683597Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/inference/monitor", "status_code": 200, "process_time_ms": 13.3}
# {"timestamp": "2026-09-21T07:16:13.642083Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/hub/gguf-variants", "status_code": 200, "process_time_ms": 227.2}
# {"timestamp": "2026-09-21T07:16:16.312064Z", "level": "info", "event": "hub_download_progress", "repo_id": "unsloth/MiniMax-H3-GGUF", "variant": "minimax_h3_fl2va_pruned-Q4_K", "percent": 60}
# {"timestamp": "2026-09-21T07:16:22.731230Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/inference/monitor", "status_code": 200, "process_time_ms": 15.38}
# {"timestamp": "2026-09-21T07:16:22.964646Z", "level": "info", "event": "hub_download_progress", "repo_id": "unsloth/MiniMax-H3-GGUF", "variant": "minimax_h3_fl2va_pruned-Q4_K", "percent": 70}
# {"timestamp": "2026-09-21T07:16:26.390071Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/studio/download-transport-capabilities", "status_code": 200, "process_time_ms": 173.62}
# {"timestamp": "2026-09-21T07:16:27.345296Z", "level": "info", "event": "hub_download_progress", "repo_id": "unsloth/MiniMax-H3-GGUF", "variant": "minimax_h3_fl2va_pruned-Q4_K", "percent": 80}
# {"timestamp": "2026-09-21T07:16:27.379265Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/hub/gguf-variants", "status_code": 200, "process_time_ms": 1016.04}
# {"timestamp": "2026-09-21T07:16:33.273865Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/inference/monitor", "status_code": 200, "process_time_ms": 3.32}
# {"timestamp": "2026-09-21T07:16:35.680697Z", "level": "info", "event": "hub_download_progress", "repo_id": "unsloth/MiniMax-H3-GGUF", "variant": "minimax_h3_fl2va_pruned-Q4_K", "percent": 90}
# {"timestamp": "2026-09-21T07:16:41.791972Z", "level": "info", "event": "Download complete: unsloth/MiniMax-H3-GGUF [minimax_h3_fl2va_pruned-Q4_K]"}
# {"timestamp": "2026-09-21T07:16:43.844998Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/inference/monitor", "status_code": 200, "process_time_ms": 2.84}
# {"timestamp": "2026-09-21T07:16:44.548128Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/hub/gguf-variants", "status_code": 200, "process_time_ms": 187.25}
# {"timestamp": "2026-09-21T07:16:44.704391Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/models/list", "status_code": 200, "process_time_ms": 14.33}
# {"timestamp": "2026-09-21T07:16:44.795309Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/inference/status", "status_code": 200, "process_time_ms": 111.21}
# {"timestamp": "2026-09-21T07:16:44.800471Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/settings/embedding-model", "status_code": 200, "process_time_ms": 109.3}
# {"timestamp": "2026-09-21T07:16:44.802253Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/hub/hidden-models", "status_code": 200, "process_time_ms": 104.98}
# {"timestamp": "2026-09-21T07:16:45.465630Z", "level": "info", "event": "Cached model scan: inspected=1 skipped_gguf=1 skipped_no_weights=0 returned=0"}
# {"timestamp": "2026-09-21T07:16:45.469741Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/hub/cached-models", "status_code": 200, "process_time_ms": 131.75}
# {"timestamp": "2026-09-21T07:16:45.477037Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/hub/local", "status_code": 200, "process_time_ms": 150.25}
# {"timestamp": "2026-09-21T07:16:45.480237Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/hub/cached-gguf", "status_code": 200, "process_time_ms": 147.61}
# {"timestamp": "2026-09-21T07:16:46.014202Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/hub/gguf-variants", "status_code": 200, "process_time_ms": 208.89}
# {"timestamp": "2026-09-21T07:16:51.741130Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/hub/gguf-variants", "status_code": 200, "process_time_ms": 122.01}
# {"timestamp": "2026-09-21T07:16:54.361792Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/inference/monitor", "status_code": 200, "process_time_ms": 2.93}
# {"timestamp": "2026-09-21T07:16:55.154136Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/inference/status", "status_code": 200, "process_time_ms": 91.85}
# {"timestamp": "2026-09-21T07:16:56.056521Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/settings/download-transport", "status_code": 200, "process_time_ms": 101.94}
# {"timestamp": "2026-09-21T07:16:56.363992Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/studio/download-transport-capabilities", "status_code": 200, "process_time_ms": 6.51}
# {"timestamp": "2026-09-21T07:16:57.346403Z", "level": "info", "event": "Download transport for unsloth/gemma-4-E4B-it-qat-mobile-GGUF: xet (Xet (requested))"}
# {"timestamp": "2026-09-21T07:16:57.376569Z", "level": "info", "event": "request_completed", "method": "POST", "path": "/api/hub/download", "status_code": 202, "process_time_ms": 147.7}
# {"timestamp": "2026-09-21T07:16:57.636403Z", "level": "info", "event": "request_completed", "method": "POST", "path": "/api/settings/xet-notice/reserve", "status_code": 200, "process_time_ms": 13.09}
# {"timestamp": "2026-09-21T07:17:00.115861Z", "level": "info", "event": "hub_download_progress", "repo_id": "unsloth/gemma-4-E4B-it-qat-mobile-GGUF", "variant": "UD-Q2_K_XL", "percent": 0}
# {"timestamp": "2026-09-21T07:17:02.718649Z", "level": "info", "event": "hub_download_progress", "repo_id": "unsloth/gemma-4-E4B-it-qat-mobile-GGUF", "variant": "UD-Q2_K_XL", "percent": 10}
# {"timestamp": "2026-09-21T07:17:03.908875Z", "level": "info", "event": "hub_download_progress", "repo_id": "unsloth/gemma-4-E4B-it-qat-mobile-GGUF", "variant": "UD-Q2_K_XL", "percent": 20}
# {"timestamp": "2026-09-21T07:17:04.996907Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/inference/monitor", "status_code": 200, "process_time_ms": 26.52}
# {"timestamp": "2026-09-21T07:17:05.256933Z", "level": "info", "event": "hub_download_progress", "repo_id": "unsloth/gemma-4-E4B-it-qat-mobile-GGUF", "variant": "UD-Q2_K_XL", "percent": 30}
# {"timestamp": "2026-09-21T07:17:05.370882Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/inference/status", "status_code": 200, "process_time_ms": 227.85}
# {"timestamp": "2026-09-21T07:17:06.812879Z", "level": "info", "event": "hub_download_progress", "repo_id": "unsloth/gemma-4-E4B-it-qat-mobile-GGUF", "variant": "UD-Q2_K_XL", "percent": 40}
# {"timestamp": "2026-09-21T07:17:09.361279Z", "level": "info", "event": "hub_download_progress", "repo_id": "unsloth/gemma-4-E4B-it-qat-mobile-GGUF", "variant": "UD-Q2_K_XL", "percent": 50}
# {"timestamp": "2026-09-21T07:17:10.573236Z", "level": "info", "event": "hub_download_progress", "repo_id": "unsloth/gemma-4-E4B-it-qat-mobile-GGUF", "variant": "UD-Q2_K_XL", "percent": 60}
# {"timestamp": "2026-09-21T07:17:11.648456Z", "level": "info", "event": "hub_download_progress", "repo_id": "unsloth/gemma-4-E4B-it-qat-mobile-GGUF", "variant": "UD-Q2_K_XL", "percent": 70}
# {"timestamp": "2026-09-21T07:17:15.059220Z", "level": "info", "event": "hub_download_progress", "repo_id": "unsloth/gemma-4-E4B-it-qat-mobile-GGUF", "variant": "UD-Q2_K_XL", "percent": 80}
# {"timestamp": "2026-09-21T07:17:15.580439Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/inference/status", "status_code": 200, "process_time_ms": 93.3}
# {"timestamp": "2026-09-21T07:17:15.606606Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/inference/monitor", "status_code": 200, "process_time_ms": 8.27}
# {"timestamp": "2026-09-21T07:17:19.501370Z", "level": "info", "event": "hub_download_progress", "repo_id": "unsloth/gemma-4-E4B-it-qat-mobile-GGUF", "variant": "UD-Q2_K_XL", "percent": 90}
# {"timestamp": "2026-09-21T07:17:23.758946Z", "level": "info", "event": "Download complete: unsloth/gemma-4-E4B-it-qat-mobile-GGUF [UD-Q2_K_XL]"}
# {"timestamp": "2026-09-21T07:17:25.429197Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/hub/gguf-variants", "status_code": 200, "process_time_ms": 152.58}
# {"timestamp": "2026-09-21T07:17:25.567504Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/models/list", "status_code": 200, "process_time_ms": 7.0}
# {"timestamp": "2026-09-21T07:17:25.580167Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/hub/hidden-models", "status_code": 200, "process_time_ms": 6.05}
# {"timestamp": "2026-09-21T07:17:25.584802Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/settings/embedding-model", "status_code": 200, "process_time_ms": 14.12}
# {"timestamp": "2026-09-21T07:17:25.677160Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/inference/status", "status_code": 200, "process_time_ms": 99.63}
# {"timestamp": "2026-09-21T07:17:26.139786Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/inference/monitor", "status_code": 200, "process_time_ms": 4.34}
# {"timestamp": "2026-09-21T07:17:26.168257Z", "level": "info", "event": "Cached model scan: inspected=2 skipped_gguf=2 skipped_no_weights=0 returned=0"}
# {"timestamp": "2026-09-21T07:17:26.173731Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/hub/cached-models", "status_code": 200, "process_time_ms": 66.31}
# {"timestamp": "2026-09-21T07:17:26.265569Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/hub/cached-gguf", "status_code": 200, "process_time_ms": 165.13}
# {"timestamp": "2026-09-21T07:17:26.270374Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/hub/local", "status_code": 200, "process_time_ms": 167.42}
# {"timestamp": "2026-09-21T07:17:26.720128Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/hub/gguf-variants", "status_code": 200, "process_time_ms": 107.52}
# {"timestamp": "2026-09-21T07:17:35.881778Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/inference/status", "status_code": 200, "process_time_ms": 92.33}
# {"timestamp": "2026-09-21T07:17:36.748568Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/inference/monitor", "status_code": 200, "process_time_ms": 2.67}
# {"timestamp": "2026-09-21T07:17:43.724021Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/models/list", "status_code": 200, "process_time_ms": 12.45}
# {"timestamp": "2026-09-21T07:17:43.729901Z", "level": "info", "event": "Found 0 trained models in /root/.unsloth/studio/outputs"}
# {"timestamp": "2026-09-21T07:17:43.732177Z", "level": "info", "event": "Found 0 exported models in /root/.unsloth/studio/exports"}
# {"timestamp": "2026-09-21T07:17:43.828527Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/models/recommended-folders", "status_code": 200, "process_time_ms": 90.04}
# {"timestamp": "2026-09-21T07:17:43.832284Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/models/scan-folders", "status_code": 200, "process_time_ms": 92.72}
# {"timestamp": "2026-09-21T07:17:46.102687Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/inference/status", "status_code": 200, "process_time_ms": 92.76}
# {"timestamp": "2026-09-21T07:17:47.318478Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/inference/monitor", "status_code": 200, "process_time_ms": 3.09}
# {"timestamp": "2026-09-21T07:17:48.088250Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/hub/gguf-variants", "status_code": 200, "process_time_ms": 125.02}
# {"timestamp": "2026-09-21T07:17:48.246771Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/hub/gguf-variants", "status_code": 200, "process_time_ms": 285.73}
# {"timestamp": "2026-09-21T07:17:52.858126Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/system/hardware", "status_code": 200, "process_time_ms": 387.37}
# {"timestamp": "2026-09-21T07:17:53.216547Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/settings/generation-presets/video", "status_code": 200, "process_time_ms": 13.0}
# {"timestamp": "2026-09-21T07:17:53.235759Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/inference/video/gallery", "status_code": 200, "process_time_ms": 22.62}
# {"timestamp": "2026-09-21T07:17:54.095939Z", "level": "info", "event": "TrainingBackend initialized (subprocess mode)"}
# {"timestamp": "2026-09-21T07:17:54.116233Z", "level": "info", "event": "request_completed", "method": "PUT", "path": "/api/settings/generation-presets/video", "status_code": 200, "process_time_ms": 18.98}
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# WARNING:huggingface_hub.utils._http:Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# {"timestamp": "2026-09-21T07:17:54.640827Z", "level": "info", "event": "request_completed", "method": "POST", "path": "/api/inference/video/download-plan", "status_code": 200, "process_time_ms": 1131.9}
# {"timestamp": "2026-09-21T07:17:54.974742Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/settings/download-transport", "status_code": 200, "process_time_ms": 8.9}
# {"timestamp": "2026-09-21T07:17:55.252634Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/studio/download-transport-capabilities", "status_code": 200, "process_time_ms": 7.0}
# {"timestamp": "2026-09-21T07:17:56.300283Z", "level": "info", "event": "Download transport for unsloth/MiniMax-H3-GGUF: xet (Xet (requested))"}
# {"timestamp": "2026-09-21T07:17:56.434177Z", "level": "info", "event": "request_completed", "method": "POST", "path": "/api/hub/download", "status_code": 202, "process_time_ms": 247.61}
# {"timestamp": "2026-09-21T07:17:56.747771Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/inference/status", "status_code": 200, "process_time_ms": 120.92}
# {"timestamp": "2026-09-21T07:17:56.789848Z", "level": "info", "event": "request_completed", "method": "POST", "path": "/api/settings/xet-notice/reserve", "status_code": 200, "process_time_ms": 28.31}
# {"timestamp": "2026-09-21T07:17:57.855066Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/inference/monitor", "status_code": 200, "process_time_ms": 5.99}
# {"timestamp": "2026-09-21T07:17:58.590845Z", "level": "info", "event": "hub_download_progress", "repo_id": "unsloth/MiniMax-H3-GGUF", "variant": "@diffusion", "percent": 0}
# {"timestamp": "2026-09-21T07:18:00.030903Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/models/recommended-folders", "status_code": 200, "process_time_ms": 6.16}
# {"timestamp": "2026-09-21T07:18:00.101970Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/models/scan-folders", "status_code": 200, "process_time_ms": 28.59}
# {"timestamp": "2026-09-21T07:18:00.198773Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/hub/cached-gguf", "status_code": 200, "process_time_ms": 111.57}
# {"timestamp": "2026-09-21T07:18:00.566905Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/hub/local", "status_code": 200, "process_time_ms": 338.59}
# {"timestamp": "2026-09-21T07:18:00.748470Z", "level": "info", "event": "Cached model scan: inspected=2 skipped_gguf=2 skipped_no_weights=0 returned=0"}
# {"timestamp": "2026-09-21T07:18:00.750165Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/hub/cached-models", "status_code": 200, "process_time_ms": 160.2}
# {"timestamp": "2026-09-21T07:18:01.225830Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/hub/gguf-variants", "status_code": 200, "process_time_ms": 596.03}
# {"timestamp": "2026-09-21T07:18:08.414855Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/inference/status", "status_code": 200, "process_time_ms": 1669.95}
# {"timestamp": "2026-09-21T07:18:08.475849Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/inference/monitor", "status_code": 200, "process_time_ms": 22.27}
# {"timestamp": "2026-09-21T07:18:14.935492Z", "level": "info", "event": "request_completed", "method": "POST", "path": "/api/inference/video/download-plan", "status_code": 200, "process_time_ms": 1789.45}
# {"timestamp": "2026-09-21T07:18:15.115341Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/models/list", "status_code": 200, "process_time_ms": 10.28}
# {"timestamp": "2026-09-21T07:18:15.119793Z", "level": "info", "event": "Found 0 trained models in /root/.unsloth/studio/outputs"}
# {"timestamp": "2026-09-21T07:18:15.122447Z", "level": "info", "event": "Found 0 exported models in /root/.unsloth/studio/exports"}
# {"timestamp": "2026-09-21T07:18:15.138620Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/models/recommended-folders", "status_code": 200, "process_time_ms": 2.23}
# {"timestamp": "2026-09-21T07:18:15.148833Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/models/scan-folders", "status_code": 200, "process_time_ms": 6.01}
# {"timestamp": "2026-09-21T07:18:17.477946Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/inference/llama-flags", "status_code": 200, "process_time_ms": 16.7}
# {"timestamp": "2026-09-21T07:18:17.779944Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/inference/active-generations", "status_code": 200, "process_time_ms": 3.08}
# {"timestamp": "2026-09-21T07:18:43.130233Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/inference/monitor", "status_code": 200, "process_time_ms": 23386.38}
# {"timestamp": "2026-09-21T07:18:43.137487Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/models/download-progress", "status_code": 200, "process_time_ms": 24574.05}
# {"timestamp": "2026-09-21T07:18:52.548738Z", "level": "info", "event": "GGUF metadata: context_length=131072"}
# {"timestamp": "2026-09-21T07:18:52.549664Z", "level": "info", "event": "GGUF metadata: chat_template=18808 chars"}
# {"timestamp": "2026-09-21T07:18:52.550440Z", "level": "info", "event": "GGUF metadata: model supports reasoning (enable_thinking)"}
# {"timestamp": "2026-09-21T07:18:52.551634Z", "level": "info", "event": "GGUF metadata: model supports preserve_thinking"}
# {"timestamp": "2026-09-21T07:18:52.600069Z", "level": "info", "event": "GGUF metadata: model supports tool calling"}
# {"timestamp": "2026-09-21T07:18:52.611077Z", "level": "info", "event": "request_completed", "method": "PUT", "path": "/api/chat/settings", "status_code": 200, "process_time_ms": 9456.62}
# {"timestamp": "2026-09-21T07:18:52.672625Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/chat/threads/__LOCALID_4VPHmlR/forks", "status_code": 200, "process_time_ms": 43.91}
# {"timestamp": "2026-09-21T07:18:52.681128Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/rag/knowledge-bases", "status_code": 200, "process_time_ms": 54.04}
# {"timestamp": "2026-09-21T07:18:52.686683Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/chat/threads/__LOCALID_4VPHmlR", "status_code": 404, "process_time_ms": 60.09}
# {"timestamp": "2026-09-21T07:18:53.120158Z", "level": "info", "event": "request_completed", "method": "POST", "path": "/api/chat/threads", "status_code": 200, "process_time_ms": 55.67}
# {"timestamp": "2026-09-21T07:18:53.208321Z", "level": "info", "event": "request_completed", "method": "POST", "path": "/api/inference/validate", "status_code": 200, "process_time_ms": 35138.73}
# {"timestamp": "2026-09-21T07:18:53.215716Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/models/download-progress", "status_code": 200, "process_time_ms": 11.25}
# {"timestamp": "2026-09-21T07:18:53.534534Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/chat/threads/__LOCALID_4VPHmlR/messages/ouwLecv", "status_code": 404, "process_time_ms": 85.27}
# {"timestamp": "2026-09-21T07:18:53.574652Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/chat/threads/__LOCALID_4VPHmlR", "status_code": 200, "process_time_ms": 113.38}
# {"timestamp": "2026-09-21T07:18:54.552692Z", "level": "info", "event": "request_completed", "method": "POST", "path": "/api/inference/validate", "status_code": 200, "process_time_ms": 1044.97}
# {"timestamp": "2026-09-21T07:18:57.766607Z", "level": "info", "event": "request_completed", "method": "PUT", "path": "/api/chat/threads/__LOCALID_4VPHmlR/messages/ouwLecv", "status_code": 200, "process_time_ms": 219.64}
# {"timestamp": "2026-09-21T07:18:58.468000Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/inference/monitor", "status_code": 200, "process_time_ms": 24.74}
# {"timestamp": "2026-09-21T07:18:58.499691Z", "level": "info", "event": "request_completed", "method": "PUT", "path": "/api/chat/threads/__LOCALID_4VPHmlR/messages", "status_code": 200, "process_time_ms": 62.08}
# {"timestamp": "2026-09-21T07:18:58.961646Z", "level": "info", "event": "request_completed", "method": "PATCH", "path": "/api/chat/threads/__LOCALID_4VPHmlR", "status_code": 200, "process_time_ms": 107.24}
# {"timestamp": "2026-09-21T07:18:59.916502Z", "level": "info", "event": "Reusing verified cached GGUF: /root/.cache/huggingface/hub/models--unsloth--gemma-4-E4B-it-qat-mobile-GGUF/snapshots/6a6e7121b977cefd85daa8fbc538fa485e7e8b1b/gemma-4-E4B-it-qat-UD-Q2_K_XL.gguf"}
# {"timestamp": "2026-09-21T07:18:59.918072Z", "level": "info", "event": "Reusing cached mmproj: /root/.cache/huggingface/hub/models--unsloth--gemma-4-E4B-it-qat-mobile-GGUF/snapshots/6a6e7121b977cefd85daa8fbc538fa485e7e8b1b/mmproj-F16.gguf"}
# {"timestamp": "2026-09-21T07:18:59.964432Z", "level": "info", "event": "request_completed", "method": "PUT", "path": "/api/chat/threads/__LOCALID_4VPHmlR/messages", "status_code": 200, "process_time_ms": 34.87}
# {"timestamp": "2026-09-21T07:19:00.959473Z", "level": "info", "event": "Reusing cached MTP drafter: /root/.cache/huggingface/hub/models--unsloth--gemma-4-E4B-it-qat-mobile-GGUF/snapshots/6a6e7121b977cefd85daa8fbc538fa485e7e8b1b/mtp-gemma-4-E4B-it.gguf"}
# {"timestamp": "2026-09-21T07:19:04.067461Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/models/download-progress", "status_code": 200, "process_time_ms": 5.12}
# ...
# {"timestamp": "2026-09-21T07:31:11.617115Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/hub/cached-models", "status_code": 200, "process_time_ms": 3181.18}
# {"timestamp": "2026-09-21T07:31:11.646324Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/hub/cached-gguf", "status_code": 200, "process_time_ms": 3213.16}
# {"timestamp": "2026-09-21T07:31:13.583232Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/inference/monitor", "status_code": 200, "process_time_ms": 7.87}
# {"timestamp": "2026-09-21T07:31:24.508121Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/inference/monitor", "status_code": 200, "process_time_ms": 6.15}
# {"timestamp": "2026-09-21T07:31:32.221892Z", "level": "info", "event": "hub_download_progress", "repo_id": "unsloth/MiniMax-H3-GGUF", "variant": "@diffusion", "percent": 90}
# ={"timestamp": "2026-09-21T07:31:37.463359Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/inference/monitor", "status_code": 200, "process_time_ms": 16.02}
# {"timestamp": "2026-09-21T07:31:46.208692Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/settings/keyless-api-access", "status_code": 200, "process_time_ms": 58.4}
# {"timestamp": "2026-09-21T07:31:47.054093Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/settings/lan-access", "status_code": 200, "process_time_ms": 882.73}
# {"timestamp": "2026-09-21T07:31:47.060666Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/health", "status_code": 200, "process_time_ms": 29.7}
# {"timestamp": "2026-09-21T07:31:47.095802Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/inference/status", "status_code": 200, "process_time_ms": 899.47}
# {"timestamp": "2026-09-21T07:31:47.117768Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/auth/api-keys", "status_code": 200, "process_time_ms": 937.02}
# {"timestamp": "2026-09-21T07:31:47.132068Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/settings/remote-access", "status_code": 200, "process_time_ms": 938.89}
# {"timestamp": "2026-09-21T07:31:47.526193Z", "level": "info", "event": "Cached model scan: inspected=2 skipped_gguf=1 skipped_no_weights=1 returned=0"}
# {"timestamp": "2026-09-21T07:31:47.533708Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/v1/models", "status_code": 200, "process_time_ms": 1335.24}
# {"timestamp": "2026-09-21T07:31:48.061302Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/inference/monitor", "status_code": 200, "process_time_ms": 8.93}
# {"timestamp": "2026-09-21T07:31:51.657515Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/models/list", "status_code": 200, "process_time_ms": 20.52}
# {"timestamp": "2026-09-21T07:31:51.755470Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/hub/cached-gguf", "status_code": 200, "process_time_ms": 123.1}
# {"timestamp": "2026-09-21T07:31:51.757892Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/models/local", "status_code": 200, "process_time_ms": 131.43}
# {"timestamp": "2026-09-21T07:31:51.982129Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/models/gguf-variants", "status_code": 200, "process_time_ms": 354.0}
# {"timestamp": "2026-09-21T07:31:53.525094Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/models/gguf-variants", "status_code": 200, "process_time_ms": 432.29}
# {"timestamp": "2026-09-21T07:31:58.126756Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/inference/status", "status_code": 200, "process_time_ms": 15.64}
# {"timestamp": "2026-09-21T07:31:58.713706Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/inference/monitor", "status_code": 200, "process_time_ms": 3.44}
# {"timestamp": "2026-09-21T07:32:09.446040Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/inference/monitor", "status_code": 200, "process_time_ms": 3.4}
# {"timestamp": "2026-09-21T07:32:09.965578Z", "level": "info", "event": "Download complete: unsloth/MiniMax-H3-GGUF [@diffusion]"}
# {"timestamp": "2026-09-21T07:32:11.253113Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/hub/hidden-models", "status_code": 200, "process_time_ms": 8.43}
# {"timestamp": "2026-09-21T07:32:11.260037Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/models/list", "status_code": 200, "process_time_ms": 11.52}
# {"timestamp": "2026-09-21T07:32:11.277479Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/inference/status", "status_code": 200, "process_time_ms": 25.92}
# {"timestamp": "2026-09-21T07:32:11.575419Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/hub/local", "status_code": 200, "process_time_ms": 33.29}
# {"timestamp": "2026-09-21T07:32:12.361359Z", "level": "info", "event": "request_completed", "method": "PUT", "path": "/api/chat/settings", "status_code": 200, "process_time_ms": 6.83}
# {"timestamp": "2026-09-21T07:32:19.332161Z", "level": "info", "event": "request_completed", "method": "PUT", "path": "/api/settings/personalization", "status_code": 200, "process_time_ms": 6.94}
# {"timestamp": "2026-09-21T07:32:20.058685Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/inference/monitor", "status_code": 200, "process_time_ms": 3.33}
# {"timestamp": "2026-09-21T07:32:30.651895Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/inference/monitor", "status_code": 200, "process_time_ms": 3.47}
# {"timestamp": "2026-09-21T07:32:41.325024Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/inference/monitor", "status_code": 200, "process_time_ms": 3.31}
# {"timestamp": "2026-09-21T07:33:06.006117Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/models/list", "status_code": 200, "process_time_ms": 12.16}
# {"timestamp": "2026-09-21T07:33:06.015927Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/chat/threads/__LOCALID_4VPHmlR", "status_code": 200, "process_time_ms": 18.66}
# {"timestamp": "2026-09-21T07:33:06.027440Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/inference/status", "status_code": 200, "process_time_ms": 34.71}
# {"timestamp": "2026-09-21T07:33:06.029877Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/chat/threads/__LOCALID_4VPHmlR/messages", "status_code": 200, "process_time_ms": 31.62}
# {"timestamp": "2026-09-21T07:33:07.821509Z", "level": "info", "event": "request_completed", "method": "PUT", "path": "/api/chat/settings", "status_code": 200, "process_time_ms": 5.44}
# {"timestamp": "2026-09-21T07:33:34.411895Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/models/list", "status_code": 200, "process_time_ms": 11.11}
# {"timestamp": "2026-09-21T07:33:34.437328Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/chat/threads/__LOCALID_4VPHmlR", "status_code": 200, "process_time_ms": 11.76}
# {"timestamp": "2026-09-21T07:33:34.441189Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/chat/threads/__LOCALID_4VPHmlR/messages", "status_code": 200, "process_time_ms": 21.36}
# {"timestamp": "2026-09-21T07:33:34.452130Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/inference/status", "status_code": 200, "process_time_ms": 35.86}
# {"timestamp": "2026-09-21T07:33:36.030245Z", "level": "info", "event": "request_completed", "method": "PUT", "path": "/api/chat/settings", "status_code": 200, "process_time_ms": 4.68}
# {"timestamp": "2026-09-21T07:34:46.901646Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/inference/monitor", "status_code": 200, "process_time_ms": 10.84}
# {"timestamp": "2026-09-21T07:34:46.915111Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/models/list", "status_code": 200, "process_time_ms": 23.35}
# {"timestamp": "2026-09-21T07:34:46.921713Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/chat/threads/__LOCALID_4VPHmlR", "status_code": 200, "process_time_ms": 26.22}
# {"timestamp": "2026-09-21T07:34:46.927917Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/chat/threads/__LOCALID_4VPHmlR/messages", "status_code": 200, "process_time_ms": 33.11}
# {"timestamp": "2026-09-21T07:34:46.938251Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/inference/status", "status_code": 200, "process_time_ms": 41.29}
# {"timestamp": "2026-09-21T07:34:47.240426Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/models/list", "status_code": 200, "process_time_ms": 10.6}
# {"timestamp": "2026-09-21T07:34:48.592229Z", "level": "info", "event": "request_completed", "method": "PUT", "path": "/api/chat/settings", "status_code": 200, "process_time_ms": 5.18}
# {"timestamp": "2026-09-21T07:34:48.842736Z", "level": "info", "event": "request_completed", "method": "PUT", "path": "/api/settings/generation-presets/video", "status_code": 200, "process_time_ms": 6.97}
# {"timestamp": "2026-09-21T07:34:52.068953Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/", "status_code": 200, "process_time_ms": 4.33}
# {"timestamp": "2026-09-21T07:34:52.513042Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/crypto-boot.js", "status_code": 200, "process_time_ms": 11.85}
# {"timestamp": "2026-09-21T07:34:52.529125Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/theme-boot.js", "status_code": 200, "process_time_ms": 19.77}
# {"timestamp": "2026-09-21T07:34:52.540168Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/reload-snapshot.js", "status_code": 200, "process_time_ms": 20.33}
# {"timestamp": "2026-09-21T07:35:09.306755Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/health", "status_code": 200, "process_time_ms": 4.61}
# {"timestamp": "2026-09-21T07:35:11.487058Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/auth/status", "status_code": 200, "process_time_ms": 3.29}
# {"timestamp": "2026-09-21T07:35:13.049703Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/settings/hugging-face-token", "status_code": 200, "process_time_ms": 5.06}
# {"timestamp": "2026-09-21T07:35:15.051571Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/chat/settings", "status_code": 200, "process_time_ms": 18.93}
# {"timestamp": "2026-09-21T07:35:15.067717Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/skills", "status_code": 200, "process_time_ms": 8.27}
# {"timestamp": "2026-09-21T07:35:15.116691Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/hub/hidden-models", "status_code": 200, "process_time_ms": 16.5}
# {"timestamp": "2026-09-21T07:35:15.131689Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/models/list", "status_code": 200, "process_time_ms": 19.68}
# {"timestamp": "2026-09-21T07:35:15.133197Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/rag/knowledge-bases", "status_code": 200, "process_time_ms": 29.58}
# {"timestamp": "2026-09-21T07:35:15.145585Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/inference/status", "status_code": 200, "process_time_ms": 34.6}
# {"timestamp": "2026-09-21T07:35:15.249334Z", "level": "info", "event": "request_completed", "method": "POST", "path": "/api/settings/chat-preferences/migrate", "status_code": 200, "process_time_ms": 5.14}
# {"timestamp": "2026-09-21T07:35:15.751210Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/openapi.json", "status_code": 200, "process_time_ms": 19.73}
# {"timestamp": "2026-09-21T07:35:15.759738Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/chat/threads/__LOCALID_HPAvECU", "status_code": 404, "process_time_ms": 6.32}
# {"timestamp": "2026-09-21T07:35:15.788638Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/hub/local", "status_code": 200, "process_time_ms": 73.87}
# {"timestamp": "2026-09-21T07:35:16.060798Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/settings/openai-auto-switch/overrides", "status_code": 200, "process_time_ms": 17.09}
# {"timestamp": "2026-09-21T07:35:16.069296Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/inference/llama-flags", "status_code": 200, "process_time_ms": 22.55}
# {"timestamp": "2026-09-21T07:35:16.105512Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/chat/threads/__LOCALID_HPAvECU/messages", "status_code": 404, "process_time_ms": 12.14}
# {"timestamp": "2026-09-21T07:35:16.109576Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/settings/vram-budget", "status_code": 200, "process_time_ms": 20.75}
# {"timestamp": "2026-09-21T07:35:16.852535Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/models/list", "status_code": 200, "process_time_ms": 24.33}
# {"timestamp": "2026-09-21T07:35:16.899236Z", "level": "info", "event": "Found 0 trained models in /root/.unsloth/studio/outputs"}
# {"timestamp": "2026-09-21T07:35:16.910306Z", "level": "info", "event": "Found 0 exported models in /root/.unsloth/studio/exports"}
# {"timestamp": "2026-09-21T07:35:17.841654Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/chat/threads/__LOCALID_HPAvECU", "status_code": 404, "process_time_ms": 28.35}
# {"timestamp": "2026-09-21T07:35:17.942640Z", "level": "info", "event": "request_completed", "method": "POST", "path": "/api/inference/validate", "status_code": 200, "process_time_ms": 1867.33}
# {"timestamp": "2026-09-21T07:35:18.185678Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/studio/update-status", "status_code": 200, "process_time_ms": 240.49}
# {"timestamp": "2026-09-21T07:35:19.230828Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/chat/threads/__LOCALID_HPAvECU", "status_code": 404, "process_time_ms": 4.98}
# {"timestamp": "2026-09-21T07:35:20.631848Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/chat/threads/__LOCALID_HPAvECU", "status_code": 404, "process_time_ms": 14.07}
# {"timestamp": "2026-09-21T07:35:21.456554Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/studio/update-status", "status_code": 200, "process_time_ms": 630.19}
# {"timestamp": "2026-09-21T07:35:21.744462Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/chat/threads/__LOCALID_HPAvECU", "status_code": 404, "process_time_ms": 29.23}
# {"timestamp": "2026-09-21T07:35:23.250418Z", "level": "info", "event": "request_completed", "method": "POST", "path": "/api/inference/chat/count_tokens", "status_code": 200, "process_time_ms": 286.9}
# {"timestamp": "2026-09-21T07:35:26.253819Z", "level": "info", "event": "request_completed", "method": "POST", "path": "/api/inference/estimate-memory", "status_code": 200, "process_time_ms": 6428.84}
# {"timestamp": "2026-09-21T07:35:26.914895Z", "level": "info", "event": "request_completed", "method": "POST", "path": "/api/inference/estimate-memory", "status_code": 200, "process_time_ms": 7081.03}
# =

# %% [markdown]
# And we're done! If you have any questions on Unsloth, we have a [Discord](https://discord.gg/unsloth) channel! If you find any bugs or want to keep updated with the latest LLM stuff, or need help, join projects etc, feel free to join our Discord!
#
# Some other resources:
# 1. Looking to use Unsloth locally? Read our [Installation Guide](https://unsloth.ai/docs/get-started/install) for details on installing Unsloth on Windows, Docker, AMD, Intel GPUs.
# 2. Learn how to do Reinforcement Learning with our [RL Guide and notebooks](https://unsloth.ai/docs/get-started/reinforcement-learning-rl-guide).
# 3. Read our guides and notebooks for [Text-to-speech (TTS)](https://unsloth.ai/docs/basics/text-to-speech-tts-fine-tuning) and [vision](https://unsloth.ai/docs/basics/vision-fine-tuning) model support.
# 4. Explore our [LLM Tutorials Directory](https://unsloth.ai/docs/models/tutorials-how-to-fine-tune-and-run-llms) to find dedicated guides for each model.
# 5. Need help with Inference? Read our [Inference & Deployment page](https://unsloth.ai/docs/basics/inference-and-deployment) for details on using vLLM, llama.cpp, Ollama etc.
#
# <div class="align-center">
#   <a href="https://unsloth.ai"><img src="https://github.com/unslothai/unsloth/raw/main/images/unsloth%20new%20logo.png" width="115"></a>
#   <a href="https://discord.gg/unsloth"><img src="https://github.com/unslothai/unsloth/raw/main/images/Discord.png" width="145"></a>
#   <a href="https://unsloth.ai/docs/"><img src="https://github.com/unslothai/unsloth/blob/main/images/documentation%20green%20button.png?raw=true" width="125"></a>
#
#   Join Discord if you need help + ⭐️ <i>Star us on <a href="https://github.com/unslothai/unsloth">Github</a> </i> ⭐️
#
#   <b>This notebook is licensed <a href="https://github.com/unslothai/unsloth/blob/main/studio/LICENSE.AGPL-3.0">AGPL-3.0</a></b>
# </div>
